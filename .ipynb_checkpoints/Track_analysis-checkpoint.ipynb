# %% [markdown]
# # Track Analysis
# Here we try to find the track's best racing line using different methods:
# - low pass filter
# - delta progress optimisation
# - Euler's spirals (TODO)

# %% [markdown]
# ## Import modules

# %%
import math
import pandas as pd
import scipy
import numpy as np
from skopt import gp_minimize
import seaborn as sns
import matplotlib.pyplot as plt
from deepracer.tracks import TrackIO, Track
from deepracer.logs import CloudWatchLogs as cw, \
    SimulationLogsIO as slio, \
    AnalysisUtils as au, \
    PlottingUtils as pu
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-5277d9eb51df> in <module>
#       3 import scipy
#       4 import numpy as np
# ----> 5 from skopt import gp_minimize
#       6 import seaborn as sns
#       7 import matplotlib.pyplot as plt
#
# ~/.conda/envs/drlog/lib/python3.8/site-packages/skopt/__init__.py in <module>
#      52     from .optimizer import gp_minimize
#      53     from .optimizer import Optimizer
# ---> 54     from .searchcv import BayesSearchCV
#      55     from .space import Space
#      56     from .utils import dump
#
# ~/.conda/envs/drlog/lib/python3.8/site-packages/skopt/searchcv.py in <module>
#      14 from sklearn.model_selection._search import BaseSearchCV
#      15 from sklearn.utils import check_random_state
# ---> 16 from sklearn.utils.fixes import MaskedArray
#      17 from sklearn.utils.validation import indexable, check_is_fitted
#      18 try:
#
# ImportError: cannot import name 'MaskedArray' from 'sklearn.utils.fixes' (/home/gbs/.conda/envs/drlog/lib/python3.8/site-packages/sklearn/utils/fixes.py)

# %% [markdown]
# ## Load track

# %%
# !ls tracks/

# %%
tu = TrackIO()

# %%
track = tu.load_track("Spain_track")

# %% [markdown]
# # Sector builder
# Let's define sectors around the track. Mapping closest waypoint coordinates as a sector mark works well and can be used to construct interesting reward that stimulates improving every part of the track evenly.

# %%
def plot_track(t, fig=None):
    ratio = (lambda x,y: x / y)(*t.size())
    if fig is None:
        fig = plt.figure(figsize=(16,8))
    ax = fig.add_subplot()
    ax.axis('equal')
    ax.plot(*t.center_line.T, 'b')
    ax.plot(*t.outer_border.T, 'b')
    ax.plot(*t.inner_border.T, 'b')
    return ax

# %%
DENSITY = 2.0
key = lambda wpt: [int(round(c * DENSITY)) / DENSITY for c in wpt]
keys = np.array([key(w) for w in track.center_line])

# %%
ax = plot_track(track)
ax.plot(*keys.T, 'gx-')

# %% [markdown]
# # PART 1: Low pass filter
# Here we will try to get optimal path using a simple RC filter.
#
# ### Helpers

# %%
def track_distance(waypoints, i, N=1):
    next_waypoint = (i + N) % len(waypoints)
    A = np.array(waypoints[i])
    B = np.array(waypoints[next_waypoint])
    return np.linalg.norm(B - A) / N

# %%
def track_heading(waypoints, i, N=1, above=None, below=None):
    """
    Calculate track waypoints heading in radians.
    i : waypoint id
    N : waypoint look ahead
    above : indicies to tweak, values should be above PI
    below : indicies to tweak, values should be below PI
    """
    next_waypoint = (i + N) % len(waypoints)
    A = waypoints[i]
    B = waypoints[next_waypoint]
    t_heading = math.atan2(B[1] - A[1], B[0] - A[0])
    if above is not None and i in above and t_heading < 0:
        t_heading += math.pi*2
    if below is not None and i in below and t_heading > 0:
        t_heading -= math.pi*2
    return t_heading

# %%
def heading2track(heading, norms, w0, constant=None):
    """
    heading : polar coords angle
    norms : polar coords radius
    w0 : initial position
    """
    wpts = [np.array(w0)]
    for h,n in zip(heading, norms):
        polar = n * np.exp(1j * h)
        polar = np.array([np.real(polar), np.imag(polar)])
        if constant is not None:
            polar += constant * n
        wpts.append(np.array(wpts[-1]) + polar)
    return np.array(wpts[1:])

# %%
def int_heading(dheading, h0, dt, constant=0.0):
    ih = np.zeros(heading.shape)
    ih[0] = h0
    for i in range(0,len(dheading)):
        ih[i+1] = ih[i] + dheading[i] + constant * dt[i]
    return ih

# %% [markdown]
# ### Analyze
# Find a racing line.
#
# #### Tune parameters above and below
# Tune parameters so that the heading plot is continuous. Problem occurs at heading 180 deg, because it jumps to -180 deg, making it a non-differentiable step function.

# %%
above = list(range(0,25))
below = list(range(225,270)) + list(range(90,98))

# %%
ix = np.arange(len(track.center_line))
dt = np.array([track_distance(track.center_line, i, N=3) for i in ix])
t = np.cumsum(dt)
heading = np.array([track_heading(track.center_line, i, N=3, above=above, below=below) for i in ix])
d_heading = heading[1:] - heading[:-1]

# %%
plt.plot(ix, heading)

# %% [markdown]
# #### Distance and distance derivative

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
plt.plot(ix, t)
plt.subplot(122)
plt.plot(ix, dt)

# %% [markdown]
# #### After tuning
# Plot heading over distance.

# %%
plt.plot(t, heading)

# %%
plt.plot(t[:-1], d_heading)

# %% [markdown]
# ### Apply low-pass filter

# %%
def low_pass_filter(data, rc=1.0):
    xin = data[1]
    dt = data[0]
    alpha = dt / (rc + dt)
    yout = np.zeros(xin.shape)
    yout[0] = xin[0]
    for i in range(1,len(yout)):
        yout[i] = alpha[i] * xin[i] + (1.0 - alpha[i]) * yout[i-1]
    return yout

# %%
dh = d_heading
for i in range(0,1):
    dh = low_pass_filter([dt, dh], 0.4)
plt.plot(t[:-1], np.degrees(dh))
plt.plot(t[:-1], np.degrees(d_heading), '--')

# %%
hconst = 0.0 # heading constant
pconst = 0.0 # position constant
start = track.center_line[0] + np.array([0.0,0.0])
for i in [0,1,2]:
    i_heading = int_heading(dh, heading[0], dt, hconst)
    from_heading = heading2track(i_heading, dt, start, pconst)
    # Match first heading with last
    if i == 0:
        err = i_heading[0] - i_heading[-1]
        err = min(err, err - 2*math.pi)
        hconst = err / t[-1]
    # Match first position with last
    if i == 1:
        pconst = (from_heading[0] - from_heading[-1]) / t[-1]

# %% [markdown]
# YES, this is broken...
# If you have time to fix/improve it, do not hesitate. Please help

# %%
ax = plot_track(track)
ax.plot(*from_heading.T, 'ro')

# %% [markdown]
# # PART 2: Delta progress optimization
# Now let's try finding a heading that minimizes travelled distance and maximizes track progress.

# %%
def closest_waypoint(w, pos):
    d = np.ones(w.shape) * np.array(pos) - w
    d = np.linalg.norm(d, axis=1)
    return np.argmin(d)

# %%
def cost_delta(heading, prev_head, waypoints, position, look_ahead=2, r=0.2):
    """Calculate track progress and resulting cost for travelled distance.
    r=0.1 is dominant track coverage for a car with speed 1.5m/s, for exact information check tempo in Essentials notebook.
    """
    dp = r * np.array([math.cos(heading), math.sin(heading)])
    p = np.array(position) + dp
    closest = closest_waypoint(waypoints, position)
    nextw = (closest + look_ahead) % len(waypoints)
    track_d = waypoints[nextw] - waypoints[closest]
    t_heading = math.atan2(track_d[1], track_d[0])
    # calculate heading derivative
    dhead = np.cross(np.array([math.cos(prev_head), math.sin(prev_head)]), dp / r)
    # our progress is travelled distance vector along track heading
    cost = dhead / (dp @ np.array([math.cos(t_heading), math.sin(t_heading)]) + 1e-5)
    return p, cost

# %%
def loss_fn(headings):
    p0 = track.center_line[0]
    loss = 0.0
    for i in range(1,len(headings)):
        p0, cost = cost_delta(headings[i], headings[i-1], track.center_line, p0)
        loss += cost
    return loss

# %%
STEPS = 260
heading = np.zeros(STEPS + 1)
line = np.zeros((STEPS + 1, 2))
heading[0] = math.pi
line[0] = track.center_line[0]
for i in range(0,STEPS):
    f = lambda x: -cost_delta(x, track.center_line, line[i])[1]
    optimal = scipy.optimize.fmin(f, 0.0, disp=0)[0]
    heading[i + 1] = optimal
    line[i + 1] = cost_delta(optimal, track.center_line, line[i])[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-fcdc6f4d6ddf> in <module>
#       6 for i in range(0,STEPS):
#       7     f = lambda x: -cost_delta(x, track.center_line, line[i])[1]
# ----> 8     optimal = scipy.optimize.fmin(f, 0.0, disp=0)[0]
#       9     heading[i + 1] = optimal
#      10     line[i + 1] = cost_delta(optimal, track.center_line, line[i])[0]
#
# ~/.conda/envs/drlog/lib/python3.8/site-packages/scipy/optimize/optimize.py in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     441             'initial_simplex': initial_simplex}
#     442
# --> 443     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     444     if full_output:
#     445         retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# ~/.conda/envs/drlog/lib/python3.8/site-packages/scipy/optimize/optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     584
#     585     for k in range(N + 1):
# --> 586         fsim[k] = func(sim[k])
#     587
#     588     ind = numpy.argsort(fsim)
#
# ~/.conda/envs/drlog/lib/python3.8/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# <ipython-input-43-fcdc6f4d6ddf> in <lambda>(x)
#       5 line[0] = track.center_line[0]
#       6 for i in range(0,STEPS):
# ----> 7     f = lambda x: -cost_delta(x, track.center_line, line[i])[1]
#       8     optimal = scipy.optimize.fmin(f, 0.0, disp=0)[0]
#       9     heading[i + 1] = optimal
#
# TypeError: cost_delta() missing 1 required positional argument: 'position'

# %%
ax = plot_track(track)
ax.plot(*line.T, 'ro')

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-44-768550215277> in <module>
# ----> 1 import skopt
#
# ModuleNotFoundError: No module named 'skopt'

# %% [markdown]
# # Choosing steering angles
# Let's find most proper steering angles. We can use any method d_heading value.

# %%
steering = np.array([t[:-1], np.degrees(dh)])
plt.plot(*steering)
plt.plot(t[:-1], np.degrees(d_heading))

# %%
limit = np.arange(round(steering[1].min()), round(steering[1].max())+1)
pivot = np.array([len(steering.T[steering[1].round() == ang]) for ang in limit])
plt.plot(limit, pivot)
